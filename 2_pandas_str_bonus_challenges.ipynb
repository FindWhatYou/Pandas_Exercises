# %% [markdown]
# # Cars challenges

# %% [markdown]
# ###### **Exercise 1:**
# read the `vehicles.csv` and set it to a variable called `cars`. We will use it for some extra challenges.

# %%
#vehicles.csv https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K/view?usp=sharing
#cars = pd.read_csv('https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K')

# %%
# import libraries
import pandas as pd

# load data
# This code is made to load our data stored on Google Drive
def gd_path(file_id):
    """Generate a shareable link from Google Drive file id."""
    return f"https://drive.google.com/uc?export=download&id={file_id}"

# Google Drive file ids
files_id = {
    "cars": "18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K", 
}

# Read data from Google Drive
cars = pd.read_csv(gd_path(files_id["cars"]))

# %%
cars.sample(5)
# Out:
#             Make             Model  Year  Engine Displacement  Cylinders  \
# 24742    Mercury             Milan  2009                  2.3        4.0
# 9119       Dodge           Caliber  2009                  2.0        4.0
# 7410   Chevrolet  Suburban C10 2WD  1984                  6.2        8.0
# 1877         BMW             335ci  2010                  3.0        6.0
# 27780   Plymouth           Acclaim  1995                  3.0        6.0
#
#                            Transmission         Drivetrain  \
# 24742                   Automatic 5-spd  Front-Wheel Drive
# 9119   Automatic (variable gear ratios)  Front-Wheel Drive
# 7410                    Automatic 4-spd      2-Wheel Drive
# 1877                       Manual 6-spd   Rear-Wheel Drive
# 27780                   Automatic 3-spd  Front-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 24742                 Midsize Cars   Regular          14.330870        20
# 9119          Small Station Wagons   Regular          13.733750        23
# 7410   Special Purpose Vehicle 2WD    Diesel          22.481471        15
# 1877               Subcompact Cars   Premium          16.480500        17
# 27780                 Midsize Cars   Regular          15.695714        19
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 24742           28            23               386.391304            1450
# 9119            27            24               370.291667            1400
# 7410            19            17               598.823529            2150
# 1877            26            20               444.350000            2000
# 27780           24            21               423.190476            1600

# %% [markdown]
# ###### **Exercise 2:**
# create a column called `Auto` filled with either `True` or `False` depending on whether the transmission is Automatic or not.

# %%
len(cars)
cars.Transmission.sample(10)
cars.Transmission.str.contains("Auto").head(10)
cars["Auto"] = cars.Transmission.str.contains("Auto")

# %%
cars.head(10)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
# 5             Acura          2.2CL/3.0CL  1997                  2.2
# 6             Acura          2.2CL/3.0CL  1997                  2.2
# 7             Acura          2.2CL/3.0CL  1997                  3.0
# 8             Acura          2.3CL/3.0CL  1998                  2.3
# 9             Acura          2.3CL/3.0CL  1998                  2.3
#
#    Cylinders     Transmission         Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd   Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd   Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd   Rear-Wheel Drive                 Midsize Cars
# 5        4.0  Automatic 4-spd  Front-Wheel Drive              Subcompact Cars
# 6        4.0     Manual 5-spd  Front-Wheel Drive              Subcompact Cars
# 7        6.0  Automatic 4-spd  Front-Wheel Drive              Subcompact Cars
# 8        4.0  Automatic 4-spd  Front-Wheel Drive              Subcompact Cars
# 9        4.0     Manual 5-spd  Front-Wheel Drive              Subcompact Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
# 5   Regular          14.982273        20           26            22
# 6   Regular          13.733750        22           28            24
# 7   Regular          16.480500        18           26            20
# 8   Regular          14.982273        19           27            22
# 9   Regular          13.733750        21           29            24
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year   Auto
# 0               522.764706            1950   True
# 1               683.615385            2550   True
# 2               555.437500            2100   True
# 3               683.615385            2550   True
# 4               555.437500            2550   True
# 5               403.954545            1500   True
# 6               370.291667            1400  False
# 7               444.350000            1650   True
# 8               403.954545            1500   True
# 9               370.291667            1400  False

# %% [markdown]
# ###### **Exercise 3:**
# create a column called `Speeds` that contains the number of speeds each transmission has, based on the number that appears in the column `Transmission`. For example, a transmission named "Automatic 4-spd" has 4 speeds, and one named "Auto (AM6)" has 6 speeds. If you find edge cases (e.g. numbers that do not make sense, no number at all...), use your own judgement to assign values to them.
#
# Note: you will most likely need to use a "Regular Expression" (or "regex") inside of the string method. Regular expressions are sequences of characters designed to match patterns. They can become really complex (to match complex patterns), but for this case, a simple [5 minute tutorial](https://www.youtube.com/watch?v=UQQsYXa1EHs&ab_channel=Kite) or some googling should be enough. Whenever you see people writing regex in plain python, remember that you can use any regular expression directly inside of a Pandas `str` method.

# %%
cars.Transmission.str.findall(r'[0-9]').sample(10)
# Out:
# 30964    [5]
# 17887    [6]
# 5851     [4]
# 65       [4]
# 26941     []
# 17307    [5]
# 5827     [6]
# 1863     [6]
# 9932     [4]
# 20644    [5]
# Name: Transmission, dtype: object

# %%
cars.Transmission.str.findall(r'(\d)').sample(10)
cars.Transmission.str.extract(r'(\d)').sample(10)
# Out:
#        0
# 28712  5
# 15526  4
# 17782  4
# 10002  3
# 3412   4
# 17636  5
# 27487  3
# 3181   8
# 4106   4
# 26638  5

# %%
cars["Speeds"] = cars.Transmission.str.findall(r'[0-9]')
cars.head(5)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year  Auto Speeds
# 0               522.764706            1950  True    [3]
# 1               683.615385            2550  True    [3]
# 2               555.437500            2100  True    [3]
# 3               683.615385            2550  True    [3]
# 4               555.437500            2550  True    [4]

# %%
cars.Speeds.sample(10)
# Out:
# 7722     [4]
# 10314    [5]
# 3603     [4]
# 16699    [4]
# 4390     [4]
# 6800     [3]
# 33952    [5]
# 19109    [5]
# 20650    [5]
# 17359     []
# Name: Speeds, dtype: object

# %% [markdown]
# ###### **Exercise 4:**
# remove non-alphanumeric characters from the "Drivetrain" and the "Make" column

# %%
cars.Drivetrain.replace(r'\-|[0-9]\-',' ', regex=True).sample(10)
# Out:
# 20824     Wheel or All Wheel Drive
# 8748             Front Wheel Drive
# 16510             Rear Wheel Drive
# 6583              Rear Wheel Drive
# 34131            Front Wheel Drive
# 11798                  Wheel Drive
# 26783            Front Wheel Drive
# 18431              All Wheel Drive
# 11744             Rear Wheel Drive
# 26145             Rear Wheel Drive
# Name: Drivetrain, dtype: object

# %%
cars["Drivetrain"] = cars.Drivetrain.replace(r'\-|[0-9]\-',' ', regex=True)
cars.Drivetrain.sample(5)
# Out:
# 34115            Front Wheel Drive
# 20564            Front Wheel Drive
# 11085     Wheel or All Wheel Drive
# 19142     Wheel or All Wheel Drive
# 7523              Rear Wheel Drive
# Name: Drivetrain, dtype: object

# %%
cars.Make.replace(r'\-', " ", regex=True).sample(5)
# Out:
# 22178    Maserati
# 10506       Dodge
# 20428         Kia
# 8036     Chrysler
# 3065          BMW
# Name: Make, dtype: object

# %%
cars['Make'] = cars.Make.replace(r'\-',' ', regex=True)
cars.sample(5)
# Out:
#             Make                         Model  Year  Engine Displacement  \
# 27091     Nissan                     Truck 2WD  1991                  2.4
# 15593        GMC  Savana 1500/2500 AWD (cargo)  2004                  5.3
# 21633    Lincoln                       MKT FWD  2016                  3.7
# 27734    Peugeot             505 Station Wagon  1988                  2.2
# 5782   Chevrolet         Express 1500/2500 2WD  1998                  5.7
#
#        Cylinders     Transmission                 Drivetrain  \
# 27091        4.0  Automatic 4-spd           Rear Wheel Drive
# 15593        8.0  Automatic 4-spd   Wheel or All Wheel Drive
# 21633        6.0   Automatic (S6)          Front Wheel Drive
# 27734        4.0  Automatic 4-spd           Rear Wheel Drive
# 5782         8.0  Automatic 4-spd           Rear Wheel Drive
#
#                             Vehicle Class Fuel Type  Fuel Barrels/Year  \
# 27091                 Small Pickup Trucks   Regular          16.480500
# 15593                    Vans, Cargo Type   Regular          23.543571
# 21633  Standard Sport Utility Vehicle 2WD   Regular          17.347895
# 27734        Midsize-Large Station Wagons   Regular          18.311667
# 5782                 Vans, Passenger Type   Regular          23.543571
#
#        City MPG  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 27091        18           24            20               444.350000
# 15593        13           17            14               634.785714
# 21633        16           24            19               468.000000
# 27734        17           20            18               493.722222
# 5782         12           17            14               634.785714
#
#        Fuel Cost/Year  Auto Speeds
# 27091            1650  True    [4]
# 15593            2400  True    [4]
# 21633            1750  True    [6]
# 27734            1850  True    [4]
# 5782             2400  True    [4]

# %%
cars.Speeds.replace(r'\[|\]',' ', regex = True).sample(10)
# Out:
# 17758    [4]
# 26698    [4]
# 8211     [5]
# 34852    [4]
# 26246     []
# 18690    [7]
# 24460    [7]
# 6947     [4]
# 20630    [5]
# 6045     [5]
# Name: Speeds, dtype: object
